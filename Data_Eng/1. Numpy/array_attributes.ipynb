# %%
import numpy as np

arr=np.random.randint(1,50,size=(2,3))
print(arr)

print(arr.shape)
print(arr.ndim)
print(arr.size)
print(arr.dtype)
print(arr.itemsize)
print(arr.nbytes)
# Out:
# [[[39  4]
#   [ 9 48]
#   [34 39]]
#
#  [[14 39]
#   [24 29]
#   [46 39]]]
# (2, 3, 2)
# 3
# 12
# int32
# 4
# 48
